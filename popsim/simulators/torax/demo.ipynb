# %%
import os
import popsim
from torax import simulation_app
from popsim.simulators.torax.sparc_prd import get_sim
from popsim.gui import XarrayGUI

os.environ["TORAX_QLKNN_MODEL_PATH"] = popsim.TORAX_QLKNN_MODEL_PATH
ds = simulation_app.main(get_sim)

# %%
gui_hook = XarrayGUI(ds, time_dim="time", rho_dim="rho")

# %%
gui_hook.build_view().servable()
