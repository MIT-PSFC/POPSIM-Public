# %% [markdown]
# # Introduction to Building Simulation Batches
#
# The `popsim.simulate` API
#
# ## Per-Simulation Psuedo-Random Number Generator Seeds
#
# ## Generating Simulation Cases with `MultiCases` and `CombinatorialCases`
#
# ## Time-Dependent Params
# When you call the `simulate()` function...
#
#
# ### Method 1: Providing a Dictionary Mapping Time to Parameter Values
#
#
# ### Method 2: Using `popsim.interp` and Providing an Interpolated Function
