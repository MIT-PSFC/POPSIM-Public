# %% [markdown]
# An example usage with a mat file that has zeros as data.

# %%
# %load_ext autoreload
# %autoreload 2

import os

from popsim import DATA_DIR
from popsim.interfaces.meq2xarray import tcv_db_to_xr

path = os.path.join(DATA_DIR, "TCV_meqdb_template.mat")

dt = tcv_db_to_xr(path)
dt
